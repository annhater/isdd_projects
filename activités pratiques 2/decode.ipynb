# %%
filename = "phrase_codee.txt"
import vador2human

decoder_dico = vador2human.vador2human
phrase = ""

# with open(filename, "r") as fillin:
#     for line in fillin:
#         phrase += line.strip()
#         decoded_phrase_list = []
#         for letter in phrase:
#             corresponding_letter = decoder_dico[letter]
#             decoded_phrase_list.append(corresponding_letter)
#         decoded_phrase = "".join(decoded_phrase_list)
#         print(f"Phrase codée:\n{phrase}")
#         print(f"Phrase décodée:\n{decoded_phrase}")


with open(filename, "r") as fillin:
    for line in fillin:
        phrase += line.strip()
        decoded_phrase = ""
        for letter in phrase:
            decoded_phrase += decoder_dico[letter]
        print(f"Phrase codée:\n{phrase}")
        print(f"Phrase décodée:\n{decoded_phrase}")
# Out:
# Phrase codée:
# pbpjcwnsjowc njykjhzri djkarjykjxkpyykfnjywduwukjckjhn unwxxwrp djckjyjfdpokna
# Phrase décodée:
# ici dark vador le python est le meilleur langage de programmation de l univers
